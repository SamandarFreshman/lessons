# %%
import pandas as pd

# %%
df = pd.read_csv("movies.csv")

# %%
df = df[['Title','Director','Production_Budget','Running_Time_min','Release_Date','Major_Genre','IMDB_Rating','Distributor','Source','Creative_Type','Rotten_Tomatoes_Rating','IMDB_Votes']]

# %%
a = input("enter running time:")
df.query('Running_Time_min > 150')
# Out:
#                                                   Title              Director  \
# 400                                  Gone with the Wind          George Cukor
# 646                                 The English Patient     Anthony Minghella
# 1074                                               2012       Roland Emmerich
# 1141                                                Ali          Michael Mann
# 1157                                          Alexander          Oliver Stone
# 1165                                  American Gangster          Ridley Scott
# 1167                                            Amistad      Steven Spielberg
# 1236                                        The Aviator       Martin Scorsese
# 1266                                    The Dark Knight     Christopher Nolan
# 1270                The Curious Case of Benjamin Button         David Fincher
# 1290                                            Beloved        Jonathan Demme
# ...
