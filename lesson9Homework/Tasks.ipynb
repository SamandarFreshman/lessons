# %%
import sqlite3
import numpy as np
import pandas as pd

# %%
with sqlite3.connect('population.db') as con:
    df = pd.read_sql("select * from population", con = con)

# %% [markdown]
# ### Task 1

# %%
df.query("""gender == 'Female' and state == 'Florida'""").drop(columns=['id','email'])
# Out:
#       first_name  last_name  gender   salary    state
# 1            Mia  Tuddenham  Female   154398  Florida
# 48         Doris    Wolfers  Female   278456  Florida
# 96        Louisa     Lummis  Female   837109  Florida
# 116       Cicily    Rhelton  Female   523875  Florida
# 128      Kirstyn     Allbon  Female   990315  Florida
# ...          ...        ...     ...      ...      ...
# 11543    Ronnica     Hearle  Female  1276566  Florida
# 11557  Cassandra   Meriguet  Female   852177  Florida
# 11566    Camilla     Likely  Female  1996098  Florida
# 11570       Edin   Martinec  Female  1918019  Florida
# 11626    Melania    Laville  Female  1908187  Florida
#
# [477 rows x 5 columns]

# %% [markdown]
# ### Task 2

# %%
df[df['email'].str.endswith("@apache.org")].groupby('gender').agg(['count']).drop(columns=['first_name','last_name','email','salary','state'])
# Out:
#           id
#        count
# gender
# Female     8
# Male      13

# %% [markdown]
# ### Task 3

# %%
df
# Out:
#           id first_name  last_name                             email  gender  \
# 0          1      Armin    Coltart              acoltart0@abc.net.au    Male
# 1          2        Mia  Tuddenham           mtuddenham1@addthis.com  Female
# 2          3   Kirsteni   Brafield            kbrafield2@arizona.edu  Female
# 3          4     Phylis    Furlong     pfurlong3@merriam-webster.com  Female
# 4          5     Wandis  Loveredge          wloveredge4@hatena.ne.jp  Female
# ...      ...        ...        ...                               ...     ...
# 11644  11645       Nell      Perez               nperezhy@flavors.me  Female
# 11645  11646        Ugo   Pethrick            upethrickhz@discuz.net    Male
# 11646  11647   Hartwell   Hadigate             hhadigatei0@cam.ac.uk    Male
# 11647  11648      Avrit     Bastin            abastini1@symantec.com  Female
# 11648  11649   Papageno   Buchanan  pbuchanani2@pagesperso-orange.fr    Male
#
#         salary                 state
# ...

# %%
df[(df['gender'] == 'Male')&(df['salary']>1000000)].groupby('gender').agg(['count']).drop(columns=['first_name','last_name','email','state'])
# Out:
#           id salary
#        count  count
# gender
# Male    2848   2848

# %% [markdown]
# ### Task 4

# %%
df[(df['gender'] == 'Female')&(df['salary']<800000)&(df['state']=='Alabama')].drop(columns=['id','salary','email','state'])
# Out:
#        first_name    last_name  gender
# 11        Ronalda    Southcott  Female
# 172          Ilka       Stucke  Female
# 326         Monah       Cayton  Female
# 371         Helsa      Aartsen  Female
# 730        Dannie     Riccardo  Female
# 916         Lilia      Sappell  Female
# 947         Honey  Della Scala  Female
# 1033      Brianne  Rattenberie  Female
# 1177        Kasey        Biles  Female
# 1486         Erma  Matuszinski  Female
# 1633        Daryl       Assard  Female
# 1909        Randa    Husselbee  Female
# 2258      Lorilee         Wann  Female
# 2527     Maitilde        Jouen  Female
# 3127        Diana    Jovanovic  Female
# 3198         Liza      Frances  Female
# 3236       Yvette         Hoyt  Female
# 3247       Lucina       Clyant  Female
# 3676       Hattie      Bolding  Female
# 3776       Sherie     Tarquini  Female
# 4067         Lora       Lapere  Female
# 4243      Beitris        Viles  Female
# 4265        Karyn     Griffith  Female
# ...

# %% [markdown]
# ### Task 5

# %%
df
# Out:
#           id first_name  last_name                             email  gender  \
# 0          1      Armin    Coltart              acoltart0@abc.net.au    Male
# 1          2        Mia  Tuddenham           mtuddenham1@addthis.com  Female
# 2          3   Kirsteni   Brafield            kbrafield2@arizona.edu  Female
# 3          4     Phylis    Furlong     pfurlong3@merriam-webster.com  Female
# 4          5     Wandis  Loveredge          wloveredge4@hatena.ne.jp  Female
# ...      ...        ...        ...                               ...     ...
# 11644  11645       Nell      Perez               nperezhy@flavors.me  Female
# 11645  11646        Ugo   Pethrick            upethrickhz@discuz.net    Male
# 11646  11647   Hartwell   Hadigate             hhadigatei0@cam.ac.uk    Male
# 11647  11648      Avrit     Bastin            abastini1@symantec.com  Female
# 11648  11649   Papageno   Buchanan  pbuchanani2@pagesperso-orange.fr    Male
#
#         salary                 state
# ...

# %%
(
    df[(df['email'].str.endswith("@hotmail.com"))&(df['state']=="Texas")]
    .groupby('state')
    .agg(['count'])
    .drop(columns=['first_name','last_name','email','gender','salary'])
)
# Out:
# Empty DataFrame
# Columns: [(id, count)]
# Index: []

# %% [markdown]
# ### Task 6

# %%
(
    df[(df['salary'] > 400000) & 
       (df['salary'] < 900000) &
       (df['state'] == "Texas") &
       (df['gender'] == 'Male')]
    .drop(columns=['email','state','gender','id'])
    .sort_values(by='salary')
).head(40)
# Out:
#       first_name    last_name  salary
# 1495       Boris      Allnutt  401651
# 7055      Tobias    Ellacombe  404203
# 2292         Axe    Allwright  406833
# 11305   Eugenius  Billborough  412663
# 1176        Linn     Bottrill  414300
# 7156       Eugen       Lydden  420127
# 1305   Templeton       Tizard  421491
# 5177   Henderson        Lerer  422323
# 8140     Joseito        Alger  423147
# 514        Bobby        Karus  427658
# 6898     Gerardo      Deakins  433107
# 7471     Coleman      Molfino  437668
# 10057      Sayre    Trewartha  440621
# 835        Alwyn        Baden  441077
# 1288       Richy     Dodimead  443232
# 7135     Thacher     Loveland  443970
# 4409        Sven     Kingerby  455374
# 8732      Maison    Georgescu  456943
# 7310       Dewey       Astall  462457
# 498      Saundra    Danzelman  465154
# 6559       Peder       Lupson  467385
# 10582     Kellen        Stark  469547
# 1600      Elliot       Armell  469822
# 5845       Anson     Harkness  469925
# ...

# %% [markdown]
# ### Task 7

# %%
df[(df['gender'] == 'Female')&(df['salary']>500000)&(df['state']=='New York')].groupby(df['state']).agg(['count']).drop(columns=['first_name','last_name','email','state','gender','id'])
# Out:
#          salary
#           count
# state
# New York    267

# %% [markdown]
# ### Task 8

# %%
(
    df[(df['state'] == "Georgia")]
    .drop(columns=['email','state','gender','id'])
    .sort_values(by='salary', ascending=False)
).head(10)
# Out:
#      first_name last_name   salary
# 7635    Susette    Emeney  1999095
# 2330    Emeline     Bebis  1997605
# 4951       Evyn   Watkins  1994162
# 6008    Hillyer    Praton  1993907
# 658    Robinett     Mucci  1989791
# 46       Verile   Binding  1985757
# 9490  Harriette   Bonwick  1970839
# 739       Anita    Vowles  1965112
# 4081      Tiffi  Lansdown  1962952
# 3262    Haslett     Nevin  1960207

# %% [markdown]
# ### Task 9

# %%
(
    df[(df['last_name'].str.startswith('S')) & 
       (df['salary'] > 300000)]
    .drop(columns=['email','state','gender','id'])
    .sort_values(by='salary', ascending=False)
)
# Out:
#       first_name   last_name   salary
# 5765       Erena      Spaule  1998236
# 255       Thorpe     Stathor  1997998
# 11477     Keslie     Stutely  1997772
# 277        Clara      Sweett  1997675
# 2011       Lucie     Seawell  1997144
# 5294       Alida       Stave  1993518
# 9866        Kain        Scud  1993510
# 9482      Anissa     Sanford  1990429
# 1926       Anton  Sidebottom  1985185
# 7581       Keven   Schulkins  1984617

# %% [markdown]
# ### Task 10

# %%
df
# Out:
#           id first_name  last_name                             email  gender  \
# 0          1      Armin    Coltart              acoltart0@abc.net.au    Male
# 1          2        Mia  Tuddenham           mtuddenham1@addthis.com  Female
# 2          3   Kirsteni   Brafield            kbrafield2@arizona.edu  Female
# 3          4     Phylis    Furlong     pfurlong3@merriam-webster.com  Female
# 4          5     Wandis  Loveredge          wloveredge4@hatena.ne.jp  Female
# ...      ...        ...        ...                               ...     ...
# 11644  11645       Nell      Perez               nperezhy@flavors.me  Female
# 11645  11646        Ugo   Pethrick            upethrickhz@discuz.net    Male
# 11646  11647   Hartwell   Hadigate             hhadigatei0@cam.ac.uk    Male
# 11647  11648      Avrit     Bastin            abastini1@symantec.com  Female
# 11648  11649   Papageno   Buchanan  pbuchanani2@pagesperso-orange.fr    Male
#
#         salary                 state
# ...

# %%
(
    df[(df['state'] == "Oklahoma") & 
       (df['gender'] == "Female")]
    .drop(columns = ['id','first_name','last_name','email','gender'])
    .groupby('state')
    .agg(['mean'])
)
# Out:
#                 salary
#                   mean
# state
# Oklahoma  1.020988e+06

# %% [markdown]
# ### Task 11

# %%
(
    df[(df['state'] == "Florida") & 
       (df['email'].str.endswith(".net"))]
)
# Out:
#           id    first_name    last_name                         email  gender  \
# 327      328          Coop     Chaimson   cchaimson93@themeforest.net    Male
# 818      819          Jobi      Cutmere         jcutmeremq@cpanel.net  Female
# 924      925         Chris     Garfirth       cgarfirthpo@behance.net  Female
# 1101    1102         Waite    Rudderham       wrudderham2t@seesaa.net    Male
# 1242    1243            Em      Graffin      egraffin6q@clickbank.net  Female
# 1357    1358     Patrizius   Matskevich     pmatskevich9x@comcast.net    Male
# 1718    1719       Malanie      Harkins         mharkinsjy@seesaa.net  Female
# 1767    1768         Abbie       Isenor             aisenorlb@php.net    Male
# 1996    1997       Eugenio      Halhead         ehalheadro@discuz.net    Male
# 2515    2516         Hobey      Licence            hlicenceeb@ovh.net    Male
# 3622    3623        Fallon        Bothe               fbotheha@a8.net  Female
# ...

# %% [markdown]
# ### Task 12

# %%
(
    df[(df['salary'] > 1000000) & 
       (df['first_name'].str.startswith("K"))]
    .groupby('gender')
    .agg(['count'])
    .drop(columns=['first_name', 'last_name','email','salary','state'])
)
# Out:
#           id
#        count
# gender
# Female   135
# Male     108

# %% [markdown]
# ### Task 13

# %%
(
    df[(df['salary'] < 200000) & 
       (df['email'].str.endswith("gmail.com"))]
)
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, email, gender, salary, state]
# Index: []

# %% [markdown]
# ### Task 14

# %%
(
    df[(df['state'] == "Ohio") & 
       (df['gender'] == "Male")]
    .drop(columns = ['id','first_name','last_name','email'])
    .groupby('gender')
    .agg(['min'])
)
# Out:
#        salary state
#           min   min
# gender
# Male    19860  Ohio

# %% [markdown]
# ### Task 15

# %%
(
    df[(df['state'] == "California") & 
       (df['salary'] > 800000) &
       (df['gender'] == "Female")]
    .drop(columns = ['id','first_name','last_name','email','state'])
    .groupby('gender')
    .agg(['count'])
)
# Out:
#        salary
#         count
# gender
# Female    400

# %% [markdown]
# ### Task 16

# %%
(
    df[(df['salary'] > 1200000) &
       (df['gender'] == "Male")]
    .drop(columns = ['id','first_name','gender','email','state'])
)
# Out:
#         last_name   salary
# 19         Dunbar  1424714
# 24      Willshear  1727275
# 53          Chick  1213441
# 63         Persey  1752514
# 66        Redolfi  1337608
# ...           ...      ...
# 11632    Sperwell  1916655
# 11634      Carney  1212833
# 11636  Sitlington  1911043
# 11642        Iles  1607225
# 11648    Buchanan  1271538
#
# [2262 rows x 2 columns]

# %% [markdown]
# ### Task 17

# %%
(
    df[(df['salary'] > 1500000) &
       (df['email'].str.contains("edu"))]
)
# Out:
#           id first_name   last_name                      email  gender  \
# 10        11       Addi   Rucklesse      arucklessea@upenn.edu  Female
# 72        73   Granthem   Essberger  gessberger20@illinois.edu    Male
# 100      101        Gun      Cutler     gcutler2s@virginia.edu    Male
# 150      151     Caresa       Takis      ctakis46@illinois.edu  Female
# 235      236  Gaultiero      Duddle       gduddle6j@utexas.edu    Male
# ...      ...        ...         ...                        ...     ...
# 11383  11384        Nye      Cloutt          nclouttap@mit.edu    Male
# 11402  11403     Sylvia     Millins         smillinsb8@umn.edu  Female
# 11554  11555        Von    McKinnon         vmckinnonfg@si.edu    Male
# 11602  11603     Krissy    Goosnell      kgoosnellgs@upenn.edu  Female
# 11636  11637      Kirby  Sitlington    ksitlingtonhq@umich.edu    Male
#
#         salary                 state
# 10     1811361              New York
# 72     1587610            New Jersey
# ...

# %% [markdown]
# ### Task 18

# %%
(
    df[(df['salary'] > 100000) &
       (df['state'] == "Alabama")]
)
# Out:
#           id first_name  last_name                      email  gender  \
# 4          5     Wandis  Loveredge   wloveredge4@hatena.ne.jp  Female
# 11        12    Ronalda  Southcott    rsouthcottb@nytimes.com  Female
# 51        52      Tiena      Babbe            tbabbe1f@hp.com  Female
# 76        77       Cort     Bedson        cbedson24@apple.com    Male
# 107      108   Prentice    Mattson      pmattson2z@google.com    Male
# ...      ...        ...        ...                        ...     ...
# 11468  11469     Michal    Wolfart         mwolfartd2@ucoz.ru    Male
# 11478  11479     Emalia  Brookwood     ebrookwooddc@chron.com  Female
# 11537  11538      Joana    Mascall      jmascallez@meetup.com  Female
# 11604  11605     Janina   Caughtry  jcaughtrygu@bloglines.com  Female
# 11629  11630     Gorden    Flatman      gflatmanhj@paypal.com    Male
#
#         salary    state
# 4      1136950  Alabama
# 11      589810  Alabama
# 51     1652463  Alabama
# 76     1372677  Alabama
# ...

# %% [markdown]
# ### Task 19

# %%
(
    df[(df['salary'] > 600000) &
       (df['last_name'].str.endswith("n"))]
)
# Out:
#           id first_name   last_name                             email  gender  \
# 22        23    Gilburt      Metson              gmetsonm@cornell.edu    Male
# 26        27    Raymund    Dodgshon    rdodgshonq@cargocollective.com    Male
# 42        43    Auroora     Startin               astartin16@webs.com  Female
# 65        66      Deana      Gerran            dgerran1t@columbia.edu  Female
# 67        68   Lauretta     Creavin              lcreavin1v@patch.com  Female
# ...      ...        ...         ...                               ...     ...
# 11629  11630     Gorden     Flatman             gflatmanhj@paypal.com    Male
# 11636  11637      Kirby  Sitlington           ksitlingtonhq@umich.edu    Male
# 11638  11639       Ania     Scotson              ascotsonhs@wiley.com  Female
# 11647  11648      Avrit      Bastin            abastini1@symantec.com  Female
# 11648  11649   Papageno    Buchanan  pbuchanani2@pagesperso-orange.fr    Male
#
#         salary         state
# ...

# %% [markdown]
# ### Task 20

# %%
(
    df[(df['state'] == "District of Columbia")]
    .drop(columns = ['id','first_name','last_name','email','gender'])
    .groupby('state')
    .agg(['max'])
)
# Out:
#                        salary
#                           max
# state
# District of Columbia  1997136

# %% [markdown]
# ### Task 21

# %%
(
    df[(df['salary'] > 500000) &
       (df['salary'] < 1000000) &
       (df['state'] == "Alabama") & 
       (df['gender'] == "Female")]
)
# Out:
#           id  first_name    last_name                          email  gender  \
# 11        12     Ronalda    Southcott        rsouthcottb@nytimes.com  Female
# 371      372       Helsa      Aartsen          haartsenab@weebly.com  Female
# 947      948       Honey  Della Scala      hdellascalaqb@samsung.com  Female
# 1241    1242      Emilie      Fawbert     efawbert6p@hugedomains.com  Female
# 1633    1634       Daryl       Assard          dassardhl@godaddy.com  Female
# 1909    1910       Randa    Husselbee            rhusselbeep9@360.cn  Female
# 2218    2219        Erma     Cradduck         ecradduck62@scribd.com  Female
# 3127    3128       Diana    Jovanovic  djovanovic3j@businessweek.com  Female
# 3247    3248      Lucina       Clyant            lclyant6v@prweb.com  Female
# 4243    4244     Beitris        Viles           bviles6r@auda.org.au  Female
# 4369    4370    Costanza      Mulbery           cmulberya9@unblog.fr  Female
# ...

# %% [markdown]
# ### Task 22

# %%
(
    df[(df['email'].str.contains("yahoo.com")) &
       (df['state'] == "Texas")]
       .drop(columns = ['first_name','last_name','email','gender','salary'])
    .groupby('state')
    .agg(['count'])
)
# Out:
#          id
#       count
# state
# Texas     1

# %% [markdown]
# ### Task 23

# %%
df1 = ( df[(df['gender'] == 'Male') &
        (df['state'] == "California")]        
)
average = df1['salary'].mean()
df1[(df1['salary'] < average)]
# Out:
#           id first_name  last_name                          email gender  \
# 7          8       Jone     Pegden        jpegden7@washington.edu   Male
# 49        50     August  D'Ambrosi        adambrosi1d@jiathis.com   Male
# 86        87     Emmott    Smeeton      esmeeton2e@guardian.co.uk   Male
# 157      158  Francklyn       Eake              feake4d@imgur.com   Male
# 204      205      Ferdy   Dumbrall           fdumbrall5o@tamu.edu   Male
# ...      ...        ...        ...                            ...    ...
# 11412  11413   Anatollo     Fearon            afearonbi@fotki.com   Male
# 11427  11428     Pepito      Asaaf            pasaafbx@seesaa.net   Male
# 11453  11454     Tammie    Whybray              twhybraycn@un.org   Male
# 11504  11505     Morten    Biddiss               mbiddisse2@ow.ly   Male
# 11627  11628    Gerrard     Bridge  gbridgehh@creativecommons.org   Male
#
#        salary       state
# 7      327962  California
# 49     741351  California
# ...
